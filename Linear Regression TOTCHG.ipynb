# %%
import pandas as pd # for Data Manipulation

# %%
import numpy as np # for storing the values in an array

# %%
import matplotlib.pyplot as plt # for plotting the Graphs/Charts

# %%
import seaborn as sns # for visualisation

# %%
#to include graph in notebook
# %matplotlib inline

# %%
#reading the csv file
df=pd.read_csv("linear_regression_dataset (6).csv") #Actual Data
#df=pd.read_csv("linear_regression_dataset (6).csv") #Test Data

# %%
df.head()
# Out:
#    AGE  FEMALE  LOS  RACE  TOTCHG  APRDRG
# 0   17       1    2   1.0    2660     560
# 1   17       0    2   1.0    1689     753
# 2   17       1    7   1.0   20060     930
# 3   17       1    1   1.0     736     758
# 4   17       1    1   1.0    1194     754

# %%
sns.set()

# %%
plt.rcParams["patch.force_edgecolor"]=True

# %%
plt.rcParams['axes.labelweight']='bold'

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AGE     500 non-null    int64
#  1   FEMALE  500 non-null    int64
#  2   LOS     500 non-null    int64
#  3   RACE    499 non-null    float64
#  4   TOTCHG  500 non-null    int64
#  5   APRDRG  500 non-null    int64
# dtypes: float64(1), int64(5)
# memory usage: 23.6 KB

# %%
df.describe()
# Out:
#               AGE      FEMALE         LOS        RACE        TOTCHG  \
# count  500.000000  500.000000  500.000000  499.000000    500.000000
# mean     5.086000    0.512000    2.828000    1.078156   2774.388000
# std      6.949474    0.500357    3.363487    0.514746   3888.407367
# min      0.000000    0.000000    0.000000    1.000000    532.000000
# 25%      0.000000    0.000000    2.000000    1.000000   1216.250000
# 50%      0.000000    1.000000    2.000000    1.000000   1536.500000
# 75%     13.000000    1.000000    3.000000    1.000000   2530.250000
# max     17.000000    1.000000   41.000000    6.000000  48388.000000
#
#            APRDRG
# count  500.000000
# mean   616.360000
# std    178.316044
# min     21.000000
# 25%    640.000000
# 50%    640.000000
# 75%    751.000000
# max    952.000000

# %%
from scipy.stats import norm
from scipy import stats
plt.figure(figsize=(12,6))
sns.distplot(df['TOTCHG'])
fig=plt.figure(figsize=(12,6))
res=stats.probplot(df['TOTCHG'], plot=plt)

# %%
df.columns
# Out:
# Index(['AGE', 'FEMALE', 'LOS', 'RACE', 'TOTCHG', 'APRDRG'], dtype='object')

# %%
df['TOTCHG'].skew()
# Out:
# 5.56111249722672

# %%
print("Skewness: {}".format(df['TOTCHG'].skew()))
print("Kurtosis: {}".format(df['TOTCHG'].kurt()))
# Out:
# Skewness: 5.56111249722672
# Kurtosis: 46.64382351855519

# %%
plt.figure(figsize=(12,6))
sns.displot(df['AGE'])
fig = plt.figure(figsize=(12,6))
res= stats.probplot(df['AGE'],plot=plt)

# %%
print("Skewness: {}".format(df['AGE'].skew()))
print("Kurtosis: {}".format(df['AGE'].kurt()))
# Out:
# Skewness: 0.7373709740106813
# Kurtosis: -1.3301615806754707

# %%
sns.pairplot(df, kind='reg')

# %%
fig= plt.figure(figsize=(12,6))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x='AGE', y='TOTCHG', data=df, kind='hex')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x=df.drop(['TOTCHG'],axis=1)
y=df['TOTCHG']

# %%
x
# Out:
#      AGE  FEMALE  LOS  RACE  APRDRG
# 0     17       1    2   1.0     560
# 1     17       0    2   1.0     753
# 2     17       1    7   1.0     930
# 3     17       1    1   1.0     758
# 4     17       1    1   1.0     754
# ..   ...     ...  ...   ...     ...
# 495    0       1    6   1.0     636
# 496    0       1    2   1.0     640
# 497    0       1    2   1.0     640
# 498    0       1    2   1.0     640
# 499    0       0    4   1.0     640
#
# [500 rows x 5 columns]

# %%
y
# Out:
# 0       2660
# 1       1689
# 2      20060
# 3        736
# 4       1194
#        ...
# 495     5881
# 496     1171
# 497     1171
# 498     1086
# 499     4931
# Name: TOTCHG, Length: 500, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
reg=LinearRegression()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [44], in <module>
# ----> 1 y_pred = np.dot(x_test)
#       2 error = (1/X_test.shape[0])*np.sum(np.abs(y_pred - Y_test))
#
# File <__array_function__ internals>:179, in dot(*args, **kwargs)
#
# TypeError: dot() missing 1 required positional argument: 'b'
